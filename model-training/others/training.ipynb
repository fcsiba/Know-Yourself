# %%
import tensorflow as tf
import pickle
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LSTM, Dropout, Activation, Embedding, Bidirectional, Concatenate

# %%
vocabulary = 5000
dimension_of_embedding = 64
words_in_a_text = 50
truncation = 'post'
padding = 'post'
not_in_vocab = '<<none>>'
training_size = 0.8

# %%
file = open('processed_list_of_tweets.pkl', 'rb')
text_data = pickle.load(file)
file.close()

# %%
file = open('processed_list_of_classes.pkl', 'rb')
text_classes = pickle.load(file)
file.close()

# %%
x = (int)(len(text_data) * training_size)

training_text = text_data[0:x]
training_classes = text_classes[0:x]

test_text = text_data[x:]
test_classes = text_classes[x:]

# %%
tokenizer = Tokenizer(num_words = vocabulary, oov_token= not_in_vocab)
tokenizer.fit_on_texts(training_text)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'<<none>>': 1,
#  'im': 2,
#  'go': 3,
#  'get': 4,
#  'feel': 5,
#  'day': 6,
#  'like': 7,
#  'love': 8,
#  'dont': 9,
#  'good': 10,
#  'work': 11,
#  'one': 12,
#  'got': 13,
#  'time': 14,
#  'want': 15,
#  'today': 16,
#  'know': 17,
#  'cant': 18,
#  'make': 19,
#  'peopl': 20,
#  'u': 21,
#  'hate': 22,
#  'see': 23,
#  'bitch': 24,
#  'think': 25,
#  'thank': 26,
#  'happi': 27,
#  'realli': 28,
#  'back': 29,
#  'need': 30,
#  'look': 31,
#  'lol': 32,
#  'miss': 33,
#  'ã': 34,
#  'rt': 35,
#  'new': 36,
#  'still': 37,
#  'come': 38,
#  'say': 39,
#  'mother': 40,
#  'friend': 41,
#  'home': 42,
#  'well': 43,
#  'much': 44,
#  'night': 45,
#  'watch': 46,
#  'na': 47,
#  'á': 48,
#  'hope': 49,
#  'would': 50,
#  'amp': 51,
#  'fuck': 52,
#  'tri': 53,
#  'thing': 54,
#  'take': 55,
#  'right': 56,
#  'last': 57,
#  'way': 58,
#  'even': 59,
#  'oh': 60,
#  'that': 61,
#  'sad': 62,
#  'great': 63,
#  'twitter': 64,
#  'nigga': 65,
#  'didnt': 66,
#  'never': 67,
#  'us': 68,
#  'week': 69,
#  'morn': 70,
#  'wish': 71,
#  'let': 72,
#  'bad': 73,
#  'call': 74,
#  'ill': 75,
#  'your': 76,
#  'could': 77,
#  'use': 78,
#  'show': 79,
#  'year': 80,
#  'start': 81,
#  'wait': 82,
#  'follow': 83,
#  'live': 84,
#  'better': 85,
#  'ive': 86,
#  'fun': 87,
#  'man': 88,
#  'tonight': 89,
#  'haha': 90,
#  'life': 91,
#  'girl': 92,
#  'talk': 93,
#  'stop': 94,
#  'littl': 95,
#  'gon': 96,
#  'play': 97,
#  'sorri': 98,
#  'sleep': 99,
#  'school': 100,
#  'someon': 101,
#  'tomorrow': 102,
#  'guy': 103,
#  'help': 104,
#  'though': 105,
#  'tweet': 106,
#  'mom': 107,
#  'angri': 108,
#  'nice': 109,
#  'hoe': 110,
#  'alway': 111,
#  'best': 112,
#  'made': 113,
#  'anoth': 114,
#  'keep': 115,
#  'yeah': 116,
#  'find': 117,
#  'someth': 118,
#  'world': 119,
#  'weekend': 120,
#  'give': 121,
#  'ass': 122,
#  'next': 123,
#  'hour': 124,
#  'long': 125,
#  'ever': 126,
#  'pleas': 127,
#  'first': 128,
#  'everyon': 129,
#  'tell': 130,
#  'thought': 131,
#  'done': 132,
#  'read': 133,
#  'said': 134,
#  'hous': 135,
#  'bed': 136,
#  'mean': 137,
#  'wont': 138,
#  'happen': 139,
#  'person': 140,
#  'fight': 141,
#  'shit': 142,
#  'movi': 143,
#  'doesnt': 144,
#  'left': 145,
#  'white': 146,
#  'ye': 147,
#  'sure': 148,
#  'lot': 149,
#  'eat': 150,
#  'trump': 151,
#  'must': 152,
#  'head': 153,
#  'hey': 154,
#  'away': 155,
#  'ur': 156,
#  'hurt': 157,
#  'everi': 158,
#  'old': 159,
#  'suck': 160,
#  'ok': 161,
#  'may': 162,
#  'final': 163,
#  'wan': 164,
#  'god': 165,
#  'tire': 166,
#  'noth': 167,
#  'leav': 168,
#  'racism': 169,
#  'saw': 170,
#  'awesom': 171,
#  'kid': 172,
#  'yet': 173,
#  'soon': 174,
#  'end': 175,
#  'antisemit': 176,
#  'also': 177,
#  'put': 178,
#  'ask': 179,
#  'sick': 180,
#  'stand': 181,
#  'phone': 182,
#  'game': 183,
#  'place': 184,
#  'alreadi': 185,
#  'mani': 186,
#  'kill': 187,
#  'hear': 188,
#  'two': 189,
#  'around': 190,
#  'parti': 191,
#  'went': 192,
#  'chang': 193,
#  'big': 194,
#  'bit': 195,
#  'faggot': 196,
#  'listen': 197,
#  'caus': 198,
#  'real': 199,
#  'disgust': 200,
#  'actual': 201,
#  'damn': 202,
#  'guess': 203,
#  'famili': 204,
#  'support': 205,
#  'money': 206,
#  'boy': 207,
#  'he': 208,
#  'hard': 209,
#  'cool': 210,
#  'believ': 211,
#  'car': 212,
#  'bore': 213,
#  'move': 214,
#  'rain': 215,
#  'without': 216,
#  'found': 217,
#  'anyon': 218,
#  'word': 219,
#  'isnt': 220,
#  'lost': 221,
#  'stay': 222,
#  'song': 223,
#  'anger': 224,
#  'face': 225,
#  'stupid': 226,
#  'enjoy': 227,
#  'mayb': 228,
#  'job': 229,
#  'sinc': 230,
#  'pretti': 231,
#  'run': 232,
#  'late': 233,
#  'id': 234,
#  'readi': 235,
#  'wrong': 236,
#  'post': 237,
#  'black': 238,
#  'babi': 239,
#  'die': 240,
#  'wow': 241,
#  'ya': 242,
#  'care': 243,
#  'mad': 244,
#  'anyth': 245,
#  'n': 246,
#  'amaz': 247,
#  'wonder': 248,
#  'check': 249,
#  'sound': 250,
#  'turn': 251,
#  'music': 252,
#  'seem': 253,
#  'friday': 254,
#  'learn': 255,
#  'cri': 256,
#  'free': 257,
#  'meet': 258,
#  'everyth': 259,
#  'book': 260,
#  'lie': 261,
#  'video': 262,
#  'monday': 263,
#  'drive': 264,
#  'told': 265,
#  'funni': 266,
#  'america': 267,
#  'name': 268,
#  'yay': 269,
#  'hot': 270,
#  'kind': 271,
#  'finish': 272,
#  'might': 273,
#  'close': 274,
#  'later': 275,
#  'ta': 276,
#  'pussi': 277,
#  'gone': 278,
#  'mine': 279,
#  'full': 280,
#  'pic': 281,
#  'rememb': 282,
#  'busi': 283,
#  'enough': 284,
#  'x': 285,
#  'glad': 286,
#  'excit': 287,
#  'star': 288,
#  'w': 289,
#  'problem': 290,
#  'crime': 291,
#  'omg': 292,
#  'food': 293,
#  'yall': 294,
#  'came': 295,
#  'month': 296,
#  'write': 297,
#  'group': 298,
#  'havent': 299,
#  'felt': 300,
#  'sit': 301,
#  'stuff': 302,
#  'yesterday': 303,
#  'heart': 304,
#  'win': 305,
#  'plan': 306,
#  'earli': 307,
#  'vote': 308,
#  'reason': 309,
#  'seen': 310,
#  'what': 311,
#  'aint': 312,
#  'birthday': 313,
#  'commun': 314,
#  'poor': 315,
#  'dog': 316,
#  'countri': 317,
#  'hair': 318,
#  'wasnt': 319,
#  'minut': 320,
#  'togeth': 321,
#  'part': 322,
#  'least': 323,
#  'cold': 324,
#  'total': 325,
#  'class': 326,
#  'cat': 327,
#  'walk': 328,
#  'quit': 329,
#  'there': 330,
#  'nigger': 331,
#  'fan': 332,
#  'racist': 333,
#  'trash': 334,
#  'onlin': 335,
#  'act': 336,
#  'send': 337,
#  'weather': 338,
#  'fail': 339,
#  'room': 340,
#  'break': 341,
#  'far': 342,
#  'hell': 343,
#  'mind': 344,
#  'ugh': 345,
#  'sun': 346,
#  'buy': 347,
#  'brother': 348,
#  'took': 349,
#  'beauti': 350,
#  'whole': 351,
#  'pictur': 352,
#  'other': 353,
#  'attack': 354,
#  'r': 355,
#  'welcom': 356,
#  'speak': 357,
#  'she': 358,
#  'news': 359,
#  'almost': 360,
#  'till': 361,
#  'violenc': 362,
#  'shop': 363,
#  'drink': 364,
#  'american': 365,
#  'cute': 366,
#  'hi': 367,
#  'hit': 368,
#  'women': 369,
#  'probabl': 370,
#  'sunday': 371,
#  'piss': 372,
#  'report': 373,
#  'forward': 374,
#  'els': 375,
#  'ago': 376,
#  'bring': 377,
#  'couldnt': 378,
#  'tv': 379,
#  'clean': 380,
#  'theyr': 381,
#  'summer': 382,
#  'dad': 383,
#  'differ': 384,
#  'pain': 385,
#  'exam': 386,
#  'sister': 387,
#  'share': 388,
#  'dinner': 389,
#  'offic': 390,
#  'parent': 391,
#  'polit': 392,
#  'open': 393,
#  'irrit': 394,
#  'true': 395,
#  'becom': 396,
#  'media': 397,
#  'understand': 398,
#  'hand': 399,
#  'fact': 400,
#  'war': 401,
#  'annoy': 402,
#  'join': 403,
#  'instead': 404,
#  'democrat': 405,
#  'okay': 406,
#  'peac': 407,
#  'heard': 408,
#  'power': 409,
#  'stori': 410,
#  'photo': 411,
#  'fear': 412,
#  'spread': 413,
#  'eye': 414,
#  'moment': 415,
#  'tho': 416,
#  'idea': 417,
#  'outsid': 418,
#  'anymor': 419,
#  'pass': 420,
#  'messag': 421,
#  'set': 422,
#  'abl': 423,
#  'wake': 424,
#  'sweet': 425,
#  'point': 426,
#  'ignor': 427,
#  'alon': 428,
#  'human': 429,
#  'aww': 430,
#  'spend': 431,
#  'hungri': 432,
#  'lunch': 433,
#  'second': 434,
#  'mum': 435,
#  'sometim': 436,
#  'bigotri': 437,
#  'updat': 438,
#  'continu': 439,
#  'team': 440,
#  'suppos': 441,
#  'holiday': 442,
#  'coffe': 443,
#  'allow': 444,
#  'fag': 445,
#  'luck': 446,
#  'citi': 447,
#  'crazi': 448,
#  'cut': 449,
#  'quot': 450,
#  'dream': 451,
#  'studi': 452,
#  'less': 453,
#  'young': 454,
#  'woke': 455,
#  'retard': 456,
#  'speech': 457,
#  'lose': 458,
#  'forgot': 459,
#  'either': 460,
#  'serious': 461,
#  'bird': 462,
#  'woman': 463,
#  'half': 464,
#  'worri': 465,
#  'anim': 466,
#  'pay': 467,
#  'text': 468,
#  'sign': 469,
#  'account': 470,
#  'high': 471,
#  'b': 472,
#  'broke': 473,
#  'aw': 474,
#  'forget': 475,
#  'upset': 476,
#  'state': 477,
#  'wear': 478,
#  'lmao': 479,
#  'pick': 480,
#  'student': 481,
#  'interest': 482,
#  'dude': 483,
#  'block': 484,
#  'comment': 485,
#  'muslim': 486,
#  'toward': 487,
#  'repli': 488,
#  'children': 489,
#  'proud': 490,
#  'offend': 491,
#  'respons': 492,
#  'jealou': 493,
#  'facebook': 494,
#  'via': 495,
#  'stuck': 496,
#  'anyway': 497,
#  'complet': 498,
#  'rest': 499,
#  'realiz': 500,
#  'men': 501,
#  'frustrat': 502,
#  'burn': 503,
#  'internet': 504,
#  'cuz': 505,
#  'gay': 506,
#  'import': 507,
#  'wit': 508,
#  'kinda': 509,
#  'rather': 510,
#  'side': 511,
#  'stress': 512,
#  'wouldnt': 513,
#  'answer': 514,
#  'boyfriend': 515,
#  'bitter': 516,
#  'yo': 517,
#  'decid': 518,
#  'past': 519,
#  'goe': 520,
#  'ppl': 521,
#  'train': 522,
#  'blog': 523,
#  'rock': 524,
#  'agre': 525,
#  'beat': 526,
#  'matter': 527,
#  'hahaha': 528,
#  'absolut': 529,
#  'dead': 530,
#  'hang': 531,
#  'shame': 532,
#  'hug': 533,
#  'email': 534,
#  'card': 535,
#  'extrem': 536,
#  'usual': 537,
#  'treat': 538,
#  'visit': 539,
#  'saturday': 540,
#  'ha': 541,
#  'issu': 542,
#  'bout': 543,
#  'link': 544,
#  'cours': 545,
#  'test': 546,
#  'child': 547,
#  'xx': 548,
#  'laugh': 549,
#  'action': 550,
#  'youtub': 551,
#  'definit': 552,
#  'rage': 553,
#  'sooo': 554,
#  'headach': 555,
#  'film': 556,
#  'fall': 557,
#  'super': 558,
#  'order': 559,
#  'site': 560,
#  'behind': 561,
#  'knew': 562,
#  'smile': 563,
#  'worst': 564,
#  'shut': 565,
#  'perfect': 566,
#  'emot': 567,
#  'da': 568,
#  'save': 569,
#  'date': 570,
#  'shoot': 571,
#  'arent': 572,
#  'dear': 573,
#  'hold': 574,
#  'uk': 575,
#  'top': 576,
#  'nation': 577,
#  'mood': 578,
#  'ugli': 579,
#  'lil': 580,
#  'question': 581,
#  'teacher': 582,
#  'ticket': 583,
#  'insult': 584,
#  'respect': 585,
#  'catch': 586,
#  'truth': 587,
#  'comput': 588,
#  'social': 589,
#  'light': 590,
#  'bother': 591,
#  'expect': 592,
#  'due': 593,
#  'bu': 594,
#  'danc': 595,
#  'celebr': 596,
#  'red': 597,
#  'bank': 598,
#  'hello': 599,
#  'especi': 600,
#  'trip': 601,
#  'line': 602,
#  'throw': 603,
#  'la': 604,
#  'drop': 605,
#  'favorit': 606,
#  'coupl': 607,
#  'drunk': 608,
#  'deal': 609,
#  'em': 610,
#  'gave': 611,
#  'leader': 612,
#  'ladi': 613,
#  'wtf': 614,
#  'remind': 615,
#  'creat': 616,
#  'season': 617,
#  'death': 618,
#  'goodnight': 619,
#  'episod': 620,
#  'bless': 621,
#  'bc': 622,
#  'dark': 623,
#  'depress': 624,
#  'water': 625,
#  'awww': 626,
#  'mommi': 627,
#  'offici': 628,
#  'evil': 629,
#  'front': 630,
#  'disappoint': 631,
#  'fine': 632,
#  'youll': 633,
#  'niggah': 634,
#  'short': 635,
#  'public': 636,
#  'promis': 637,
#  'park': 638,
#  'sing': 639,
#  'form': 640,
#  'kick': 641,
#  'iphon': 642,
#  'type': 643,
#  'color': 644,
#  'danger': 645,
#  'fix': 646,
#  'father': 647,
#  'list': 648,
#  'concert': 649,
#  'strong': 650,
#  'race': 651,
#  'law': 652,
#  'control': 653,
#  'figur': 654,
#  'ice': 655,
#  'scare': 656,
#  'discuss': 657,
#  'ad': 658,
#  'window': 659,
#  'ah': 660,
#  'insid': 661,
#  'son': 662,
#  'pull': 663,
#  'confus': 664,
#  'boo': 665,
#  'promot': 666,
#  'event': 667,
#  'beach': 668,
#  'special': 669,
#  'art': 670,
#  'wors': 671,
#  'finger': 672,
#  'lucki': 673,
#  'murder': 674,
#  'mr': 675,
#  'shot': 676,
#  'pray': 677,
#  'present': 678,
#  'maga': 679,
#  'compani': 680,
#  'fuckin': 681,
#  'page': 682,
#  'mess': 683,
#  'btw': 684,
#  'inspir': 685,
#  'fire': 686,
#  'violent': 687,
#  'fill': 688,
#  'store': 689,
#  'resist': 690,
#  'often': 691,
#  'gener': 692,
#  'rise': 693,
#  'ride': 694,
#  'bodi': 695,
#  'voic': 696,
#  'deserv': 697,
#  'accept': 698,
#  'forc': 699,
#  'presid': 700,
#  'bought': 701,
#  'abus': 702,
#  'breakfast': 703,
#  'posit': 704,
#  'town': 705,
#  'broken': 706,
#  'three': 707,
#  'servic': 708,
#  'met': 709,
#  'dress': 710,
#  'fake': 711,
#  'trek': 712,
#  'shower': 713,
#  'yea': 714,
#  'fat': 715,
#  'til': 716,
#  'horribl': 717,
#  'teach': 718,
#  'jewish': 719,
#  'youv': 720,
#  'cunt': 721,
#  'crap': 722,
#  'soo': 723,
#  'wife': 724,
#  'street': 725,
#  'possibl': 726,
#  'min': 727,
#  'piec': 728,
#  'wed': 729,
#  'rude': 730,
#  'fair': 731,
#  'road': 732,
#  'blame': 733,
#  'door': 734,
#  'cancel': 735,
#  'case': 736,
#  'club': 737,
#  'dumb': 738,
#  'number': 739,
#  'incid': 740,
#  'joke': 741,
#  'mention': 742,
#  'jew': 743,
#  'age': 744,
#  'trust': 745,
#  'longer': 746,
#  'fb': 747,
#  'relax': 748,
#  'dick': 749,
#  'taken': 750,
#  'hehe': 751,
#  'receiv': 752,
#  'tea': 753,
#  'worth': 754,
#  'polic': 755,
#  'awak': 756,
#  'soooo': 757,
#  'low': 758,
#  'project': 759,
#  'futur': 760,
#  'load': 761,
#  'chocol': 762,
#  'histori': 763,
#  'resent': 764,
#  'across': 765,
#  'includ': 766,
#  'self': 767,
#  'imagin': 768,
#  'yr': 769,
#  'fli': 770,
#  'daughter': 771,
#  'cross': 772,
#  'whatev': 773,
#  'govern': 774,
#  'notic': 775,
#  'dat': 776,
#  'travel': 777,
#  'spent': 778,
#  'build': 779,
#  'garden': 780,
#  'normal': 781,
#  'near': 782,
#  'chat': 783,
#  'everybodi': 784,
#  'destroy': 785,
#  'manag': 786,
#  'push': 787,
#  'chanc': 788,
#  'pack': 789,
#  'none': 790,
#  'rip': 791,
#  'motiv': 792,
#  'grow': 793,
#  'air': 794,
#  'outrag': 795,
#  'educ': 796,
#  'smh': 797,
#  'graduat': 798,
#  'colleg': 799,
#  'cook': 800,
#  'exactli': 801,
#  'small': 802,
#  'charg': 803,
#  'invit': 804,
#  'record': 805,
#  'yep': 806,
#  'divis': 807,
#  'along': 808,
#  'liber': 809,
#  'fast': 810,
#  'success': 811,
#  'sent': 812,
#  'express': 813,
#  'surpris': 814,
#  'leg': 815,
#  'slow': 816,
#  'church': 817,
#  'afternoon': 818,
#  'victim': 819,
#  'easi': 820,
#  'attent': 821,
#  'lead': 822,
#  'societi': 823,
#  'singl': 824,
#  'husband': 825,
#  'tear': 826,
#  'nobodi': 827,
#  'refus': 828,
#  'english': 829,
#  'sadli': 830,
#  'laptop': 831,
#  'arriv': 832,
#  'asleep': 833,
#  'appreci': 834,
#  'paper': 835,
#  'view': 836,
#  'nap': 837,
#  'add': 838,
#  'rush': 839,
#  'design': 840,
#  'gt': 841,
#  'entir': 842,
#  'etc': 843,
#  'goin': 844,
#  'clear': 845,
#  'huge': 846,
#  'cover': 847,
#  'result': 848,
#  'bulli': 849,
#  'situat': 850,
#  'fell': 851,
#  'girlfriend': 852,
#  'upload': 853,
#  'india': 854,
#  'current': 855,
#  'download': 856,
#  'return': 857,
#  'ate': 858,
#  'unit': 859,
#  'somebodi': 860,
#  'count': 861,
#  'unfortun': 862,
#  'sore': 863,
#  'cream': 864,
#  'wast': 865,
#  'bill': 866,
#  'gym': 867,
#  'practic': 868,
#  'christian': 869,
#  'experi': 870,
#  'sunni': 871,
#  'xd': 872,
#  'warm': 873,
#  'king': 874,
#  'combat': 875,
#  'sell': 876,
#  'arm': 877,
#  'meant': 878,
#  'hospit': 879,
#  'choos': 880,
#  'except': 881,
#  'bday': 882,
#  'bet': 883,
#  'chill': 884,
#  'brain': 885,
#  'gift': 886,
#  'lesson': 887,
#  'appar': 888,
#  'convers': 889,
#  'ball': 890,
#  'target': 891,
#  'ruin': 892,
#  'ipod': 893,
#  'apart': 894,
#  'certain': 895,
#  'cousin': 896,
#  'cake': 897,
#  'campaign': 898,
#  'protect': 899,
#  'mark': 900,
#  'recent': 901,
#  'usa': 902,
#  'memori': 903,
#  'sever': 904,
#  'safe': 905,
#  'smell': 906,
#  'lame': 907,
#  'seriou': 908,
#  'p': 909,
#  'terribl': 910,
#  'folk': 911,
#  'sigh': 912,
#  'note': 913,
#  'touch': 914,
#  'sat': 915,
#  'forev': 916,
#  'obama': 917,
#  'draw': 918,
#  'track': 919,
#  'sort': 920,
#  'paid': 921,
#  'terror': 922,
#  'blood': 923,
#  'tour': 924,
#  'straight': 925,
#  'bag': 926,
#  'interview': 927,
#  'app': 928,
#  'reveng': 929,
#  'ran': 930,
#  'discrimin': 931,
#  'weird': 932,
#  'articl': 933,
#  'bike': 934,
#  'canada': 935,
#  'c': 936,
#  'neg': 937,
#  'shouldnt': 938,
#  'lone': 939,
#  'releas': 940,
#  'band': 941,
#  'mama': 942,
#  'mile': 943,
#  'kiss': 944,
#  'cloth': 945,
#  'xxx': 946,
#  'appear': 947,
#  'hatr': 948,
#  'quick': 949,
#  'wash': 950,
#  'middl': 951,
#  'smoke': 952,
#  'doctor': 953,
#  'blue': 954,
#  'traffic': 955,
#  'platform': 956,
#  'dem': 957,
#  'throat': 958,
#  'beer': 959,
#  'june': 960,
#  'gop': 961,
#  'heat': 962,
#  'bro': 963,
#  'furiou': 964,
#  'opinion': 965,
#  'cheer': 966,
#  'truli': 967,
#  'snap': 968,
#  'shoe': 969,
#  'liter': 970,
#  'dm': 971,
#  'version': 972,
#  'nope': 973,
#  'revis': 974,
#  'toler': 975,
#  'given': 976,
#  'femal': 977,
#  'greedi': 978,
#  'websit': 979,
#  'bar': 980,
#  'london': 981,
#  'consid': 982,
#  'distract': 983,
#  'member': 984,
#  'seat': 985,
#  'energi': 986,
#  'green': 987,
#  'plu': 988,
#  'album': 989,
#  'local': 990,
#  'appl': 991,
#  'who': 992,
#  'howev': 993,
#  'footbal': 994,
#  'selfish': 995,
#  'box': 996,
#  'googl': 997,
#  'direct': 998,
#  'earlier': 999,
#  'gun': 1000,
#  ...}

# %%
training_text_sequences = tokenizer.texts_to_sequences(training_text)

training_text_padded = pad_sequences(training_text_sequences, maxlen=words_in_a_text, padding=padding, truncating=truncation)

# %%
test_text_sequences = tokenizer.texts_to_sequences(test_text)

test_text_padded = pad_sequences(test_text_sequences, maxlen=words_in_a_text, padding=padding, truncating=truncation)

# %%
print(set(text_classes))
# Out:
# {'hate', 'neutral', 'sad', 'anger', 'happy'}

# %%
class_tokenizer = Tokenizer()
class_tokenizer.fit_on_texts(text_classes)

training_classes_sequences = np.array(class_tokenizer.texts_to_sequences(training_classes))
test_classes_sequences = np.array(class_tokenizer.texts_to_sequences(test_classes))

# %%
model = Sequential()
model.add(Embedding(vocabulary,dimension_of_embedding))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(dimension_of_embedding)))
model.add(Dense(6, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_19 (Embedding)     (None, None, 64)          320000
# _________________________________________________________________
# dropout_19 (Dropout)         (None, None, 64)          0
# _________________________________________________________________
# bidirectional_23 (Bidirectio (None, 128)               66048
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 386,822
# Trainable params: 386,822
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(lr=0.001, decay=1e-6)
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=opt,
    metrics=['accuracy'],
)

# %%
history = model.fit(training_text_padded, training_classes_sequences, epochs=100, validation_data=(test_text_padded, test_classes_sequences), verbose=2)
# Out:
# Train on 50512 samples, validate on 12628 samples
# Epoch 1/100
# 50512/50512 - 137s - loss: 1.0778 - acc: 0.5494 - val_loss: 0.9372 - val_acc: 0.6268
# Epoch 2/100
# 50512/50512 - 150s - loss: 0.8843 - acc: 0.6492 - val_loss: 0.9245 - val_acc: 0.6309
# Epoch 3/100
# 50512/50512 - 153s - loss: 0.8364 - acc: 0.6710 - val_loss: 0.9371 - val_acc: 0.6265
# Epoch 4/100
# 50512/50512 - 145s - loss: 0.8024 - acc: 0.6863 - val_loss: 0.9492 - val_acc: 0.6240
# Epoch 5/100
# 50512/50512 - 137s - loss: 0.7716 - acc: 0.6961 - val_loss: 0.9682 - val_acc: 0.6216
# Epoch 6/100
# 50512/50512 - 136s - loss: 0.7460 - acc: 0.7084 - val_loss: 0.9743 - val_acc: 0.6224
# Epoch 7/100
# 50512/50512 - 137s - loss: 0.7159 - acc: 0.7201 - val_loss: 1.0121 - val_acc: 0.6178
# Epoch 8/100
# 50512/50512 - 135s - loss: 0.6891 - acc: 0.7302 - val_loss: 1.0400 - val_acc: 0.6129
# Epoch 9/100
# 50512/50512 - 135s - loss: 0.6660 - acc: 0.7396 - val_loss: 1.0702 - val_acc: 0.6107
# Epoch 10/100
# 50512/50512 - 139s - loss: 0.6439 - acc: 0.7478 - val_loss: 1.1020 - val_acc: 0.6082
# Epoch 11/100
# 50512/50512 - 136s - loss: 0.6210 - acc: 0.7579 - val_loss: 1.1401 - val_acc: 0.6027
# Epoch 12/100
# 50512/50512 - 136s - loss: 0.6011 - acc: 0.7644 - val_loss: 1.1648 - val_acc: 0.6006
# Epoch 13/100
# 50512/50512 - 141s - loss: 0.5800 - acc: 0.7722 - val_loss: 1.2017 - val_acc: 0.6003
# Epoch 14/100
# 50512/50512 - 136s - loss: 0.5613 - acc: 0.7823 - val_loss: 1.2350 - val_acc: 0.5991
# Epoch 15/100
# 50512/50512 - 137s - loss: 0.5455 - acc: 0.7869 - val_loss: 1.2760 - val_acc: 0.5943
# Epoch 16/100
# 50512/50512 - 135s - loss: 0.5294 - acc: 0.7938 - val_loss: 1.3023 - val_acc: 0.5939
# Epoch 17/100
# 50512/50512 - 135s - loss: 0.5104 - acc: 0.8024 - val_loss: 1.3648 - val_acc: 0.5961
# Epoch 18/100
# 50512/50512 - 137s - loss: 0.4985 - acc: 0.8073 - val_loss: 1.3973 - val_acc: 0.5921
# Epoch 19/100
# 50512/50512 - 146s - loss: 0.4822 - acc: 0.8113 - val_loss: 1.4243 - val_acc: 0.5931
# Epoch 20/100
# 50512/50512 - 150s - loss: 0.4705 - acc: 0.8179 - val_loss: 1.4632 - val_acc: 0.5919
# Epoch 21/100
# 50512/50512 - 142s - loss: 0.4598 - acc: 0.8220 - val_loss: 1.4768 - val_acc: 0.5882
# Epoch 22/100
# 50512/50512 - 149s - loss: 0.4482 - acc: 0.8259 - val_loss: 1.5165 - val_acc: 0.5902
# Epoch 23/100
# 50512/50512 - 143s - loss: 0.4373 - acc: 0.8294 - val_loss: 1.5362 - val_acc: 0.5877
# Epoch 24/100
# 50512/50512 - 144s - loss: 0.4267 - acc: 0.8341 - val_loss: 1.5616 - val_acc: 0.5828
# Epoch 25/100
# 50512/50512 - 134s - loss: 0.4176 - acc: 0.8394 - val_loss: 1.6026 - val_acc: 0.5881
# Epoch 26/100
# 50512/50512 - 135s - loss: 0.4067 - acc: 0.8435 - val_loss: 1.6491 - val_acc: 0.5812
# Epoch 27/100
# 50512/50512 - 135s - loss: 0.4000 - acc: 0.8449 - val_loss: 1.6760 - val_acc: 0.5810
# Epoch 28/100
# 50512/50512 - 134s - loss: 0.3900 - acc: 0.8502 - val_loss: 1.7344 - val_acc: 0.5815
# Epoch 29/100
# 50512/50512 - 134s - loss: 0.3867 - acc: 0.8507 - val_loss: 1.7329 - val_acc: 0.5854
# Epoch 30/100
# 50512/50512 - 134s - loss: 0.3797 - acc: 0.8546 - val_loss: 1.7331 - val_acc: 0.5776
# Epoch 31/100
# 50512/50512 - 134s - loss: 0.3698 - acc: 0.8579 - val_loss: 1.7717 - val_acc: 0.5766
# Epoch 32/100
# 50512/50512 - 134s - loss: 0.3648 - acc: 0.8599 - val_loss: 1.7759 - val_acc: 0.5810
# Epoch 33/100
# 50512/50512 - 134s - loss: 0.3582 - acc: 0.8627 - val_loss: 1.8123 - val_acc: 0.5770
# Epoch 34/100
# 50512/50512 - 136s - loss: 0.3553 - acc: 0.8631 - val_loss: 1.8328 - val_acc: 0.5745
# Epoch 35/100
# 50512/50512 - 148s - loss: 0.3470 - acc: 0.8677 - val_loss: 1.8285 - val_acc: 0.5776
# Epoch 36/100
# 50512/50512 - 133s - loss: 0.3401 - acc: 0.8691 - val_loss: 1.8956 - val_acc: 0.5763
# Epoch 37/100
# 50512/50512 - 134s - loss: 0.3377 - acc: 0.8702 - val_loss: 1.8752 - val_acc: 0.5717
# Epoch 38/100
# 50512/50512 - 134s - loss: 0.3284 - acc: 0.8741 - val_loss: 1.9497 - val_acc: 0.5790
# Epoch 39/100
# 50512/50512 - 134s - loss: 0.3279 - acc: 0.8754 - val_loss: 1.9008 - val_acc: 0.5733
# Epoch 40/100
# 50512/50512 - 134s - loss: 0.3272 - acc: 0.8764 - val_loss: 1.9331 - val_acc: 0.5734
# Epoch 41/100
# 50512/50512 - 133s - loss: 0.3212 - acc: 0.8779 - val_loss: 1.9344 - val_acc: 0.5755
# Epoch 42/100
# 50512/50512 - 134s - loss: 0.3139 - acc: 0.8818 - val_loss: 1.9445 - val_acc: 0.5761
# Epoch 43/100
# 50512/50512 - 134s - loss: 0.3156 - acc: 0.8798 - val_loss: 1.9654 - val_acc: 0.5759
# Epoch 44/100
# 50512/50512 - 134s - loss: 0.3083 - acc: 0.8827 - val_loss: 2.0001 - val_acc: 0.5748
# Epoch 45/100
# 50512/50512 - 133s - loss: 0.3077 - acc: 0.8822 - val_loss: 2.0280 - val_acc: 0.5779
# Epoch 46/100
# 50512/50512 - 133s - loss: 0.3024 - acc: 0.8863 - val_loss: 1.9980 - val_acc: 0.5715
# Epoch 47/100
# 50512/50512 - 133s - loss: 0.3000 - acc: 0.8856 - val_loss: 1.9826 - val_acc: 0.5734
# Epoch 48/100
# 50512/50512 - 133s - loss: 0.2986 - acc: 0.8874 - val_loss: 2.0411 - val_acc: 0.5745
# Epoch 49/100
# 50512/50512 - 133s - loss: 0.2963 - acc: 0.8867 - val_loss: 1.9857 - val_acc: 0.5759
# Epoch 50/100
# 50512/50512 - 134s - loss: 0.2915 - acc: 0.8894 - val_loss: 2.0108 - val_acc: 0.5717
# Epoch 51/100
# 50512/50512 - 134s - loss: 0.2898 - acc: 0.8902 - val_loss: 2.0287 - val_acc: 0.5751
# Epoch 52/100
# 50512/50512 - 134s - loss: 0.2846 - acc: 0.8927 - val_loss: 2.1013 - val_acc: 0.5717
# Epoch 53/100
# 50512/50512 - 134s - loss: 0.2794 - acc: 0.8950 - val_loss: 2.0671 - val_acc: 0.5715
# Epoch 54/100
# 50512/50512 - 134s - loss: 0.2817 - acc: 0.8940 - val_loss: 2.0848 - val_acc: 0.5725
# Epoch 55/100
# 50512/50512 - 134s - loss: 0.2817 - acc: 0.8932 - val_loss: 2.1000 - val_acc: 0.5713
# Epoch 56/100
# 50512/50512 - 134s - loss: 0.2747 - acc: 0.8962 - val_loss: 2.1014 - val_acc: 0.5704
# Epoch 57/100
# 50512/50512 - 133s - loss: 0.2735 - acc: 0.8977 - val_loss: 2.1194 - val_acc: 0.5710
# Epoch 58/100
# 50512/50512 - 134s - loss: 0.2745 - acc: 0.8956 - val_loss: 2.1340 - val_acc: 0.5709
# Epoch 59/100
# 50512/50512 - 133s - loss: 0.2703 - acc: 0.8983 - val_loss: 2.1645 - val_acc: 0.5727
# Epoch 60/100
# 50512/50512 - 134s - loss: 0.2709 - acc: 0.8974 - val_loss: 2.1192 - val_acc: 0.5688
# Epoch 61/100
# 50512/50512 - 136s - loss: 0.2678 - acc: 0.8989 - val_loss: 2.1138 - val_acc: 0.5666
# Epoch 62/100
# 50512/50512 - 139s - loss: 0.2633 - acc: 0.8998 - val_loss: 2.1651 - val_acc: 0.5726
# Epoch 63/100
# 50512/50512 - 134s - loss: 0.2667 - acc: 0.8995 - val_loss: 2.1571 - val_acc: 0.5664
# Epoch 64/100
# 50512/50512 - 139s - loss: 0.2627 - acc: 0.9008 - val_loss: 2.1499 - val_acc: 0.5693
# Epoch 65/100
# 50512/50512 - 141s - loss: 0.2626 - acc: 0.9012 - val_loss: 2.1752 - val_acc: 0.5710
# Epoch 66/100
# 50512/50512 - 147s - loss: 0.2646 - acc: 0.9008 - val_loss: 2.1804 - val_acc: 0.5689
# Epoch 67/100
# 50512/50512 - 144s - loss: 0.2593 - acc: 0.9016 - val_loss: 2.1695 - val_acc: 0.5736
# Epoch 68/100
# 50512/50512 - 148s - loss: 0.2603 - acc: 0.9014 - val_loss: 2.1609 - val_acc: 0.5685
# Epoch 69/100
# 50512/50512 - 141s - loss: 0.2556 - acc: 0.9043 - val_loss: 2.1614 - val_acc: 0.5740
# Epoch 70/100
# 50512/50512 - 136s - loss: 0.2528 - acc: 0.9057 - val_loss: 2.1714 - val_acc: 0.5678
# Epoch 71/100
# 50512/50512 - 134s - loss: 0.2498 - acc: 0.9064 - val_loss: 2.2004 - val_acc: 0.5716
# Epoch 72/100
# 50512/50512 - 134s - loss: 0.2499 - acc: 0.9066 - val_loss: 2.1782 - val_acc: 0.5666
# Epoch 73/100
# 50512/50512 - 134s - loss: 0.2478 - acc: 0.9072 - val_loss: 2.2285 - val_acc: 0.5682
# Epoch 74/100
# 50512/50512 - 134s - loss: 0.2460 - acc: 0.9067 - val_loss: 2.2486 - val_acc: 0.5701
# Epoch 75/100
# 50512/50512 - 134s - loss: 0.2451 - acc: 0.9089 - val_loss: 2.2458 - val_acc: 0.5708
# Epoch 76/100
# 50512/50512 - 134s - loss: 0.2472 - acc: 0.9058 - val_loss: 2.2295 - val_acc: 0.5699
# Epoch 77/100
# 50512/50512 - 134s - loss: 0.2423 - acc: 0.9096 - val_loss: 2.2723 - val_acc: 0.5651
# Epoch 78/100
# 50512/50512 - 137s - loss: 0.2446 - acc: 0.9071 - val_loss: 2.2490 - val_acc: 0.5701
# Epoch 79/100
# 50512/50512 - 134s - loss: 0.2418 - acc: 0.9089 - val_loss: 2.2496 - val_acc: 0.5710
# Epoch 80/100
# 50512/50512 - 149s - loss: 0.2418 - acc: 0.9089 - val_loss: 2.2727 - val_acc: 0.5692
# Epoch 81/100
# 50512/50512 - 232s - loss: 0.2391 - acc: 0.9112 - val_loss: 2.2768 - val_acc: 0.5700
# Epoch 82/100
# 50512/50512 - 270s - loss: 0.2391 - acc: 0.9101 - val_loss: 2.2527 - val_acc: 0.5709
# Epoch 83/100
# 50512/50512 - 267s - loss: 0.2352 - acc: 0.9126 - val_loss: 2.2977 - val_acc: 0.5715
# Epoch 84/100
# 50512/50512 - 277s - loss: 0.2382 - acc: 0.9103 - val_loss: 2.3011 - val_acc: 0.5721
# Epoch 85/100
# 50512/50512 - 254s - loss: 0.2347 - acc: 0.9126 - val_loss: 2.3006 - val_acc: 0.5697
# Epoch 86/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-8bbf6be97afa> in <module>
# ----> 1 history = model.fit(training_text_padded, training_classes_sequences, epochs=100, validation_data=(test_text_padded, test_classes_sequences), verbose=2)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
#     779           validation_freq=validation_freq,
# --> 780           steps_name='steps_per_epoch')
#     781
#     782   def evaluate(self,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     361
#     362         # Get outputs.
# --> 363         batch_outs = f(ins_batch)
#     364         if not isinstance(batch_outs, list):
#     365           batch_outs = [batch_outs]
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
